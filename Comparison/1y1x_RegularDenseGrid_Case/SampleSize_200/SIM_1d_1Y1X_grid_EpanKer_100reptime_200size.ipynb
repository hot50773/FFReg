# %%
'''
---------------------------------------------------------------
Simulation for Function-on-Function Linear Regression
---------------------------------------------------------------
* 1 d

* 1 Response Y & 1 Predictor X   

* Regular Dense Grid (num of grid: 21)

* Training samp size: 200
  Test     samp size: 100

* Using Epan Kernal Function in LPR

* Using Leave-One-Curve-Out CV for bandwidth selection in LPR 

* Using FVE = 0.98
---------------------------------------------------------------
'''
#####
import os
os.chdir('D:/Work_Jupyter/敏/')
import GetData
import FFReg
import Plotting
import lpr
import time
import scipy as sp
from scipy import io
import numpy as np
os.chdir('D:/Work_Jupyter/敏/SIM_1y1x_grid1_size200')

# ---------
# Settings
# ---------

tran_samp_size = 200
test_samp_size = 100
samp_size = tran_samp_size + test_samp_size

num_pts = 21

# -------------
# Setting of X
# -------------
def X_Mean_Func(s):
    #input, output: vector
    return(s /  + 2 * np.sin(s))

def Eigen_Funcs_X(s):
    #input  :d-vector
    #output:array with dim (2 * d)
    return(np.array([np.sqrt(2 / 5) * -np.cos(2 * np.pi * s / 5), 
                     np.sqrt(2 / 5) *  np.sin(2 * np.pi * s / 5),
                     np.sqrt(2 / 5) * -np.cos(4 * np.pi * s / 5)]))

num_grid_X = num_pts
range_X = np.array([0, 5])
X_eigen_val = np.array([9, 4, 1])

# -------------
# Setting of Y
# -------------

def Y_Mean_Func(s):
    #input, output: vector
    return(s / 2 + np.sin(s))

def Eigen_Funcs_Y(s):
    #input  :d-vector
    #output:array with dim (2 * d)
    return(np.array([np.sqrt(2 / 5) * -np.cos(np.pi * s / 5), 
                     np.sqrt(2 / 5) * np.sin(np.pi * s / 5),
                     np.sqrt(2 / 5) * -np.cos(2 * np.pi * s / 5)])) 

num_grid_Y = num_pts

range_Y = np.array([0, 5])

B = np.array([[1, 0.8, 0.8], [-1, 0.5, -0.5],[0.8, -0.5, 0.2]])

# %%
name = ['X', 'Y']

# %%
sim_rep_time = 100

# %%
# #Simulation

# np.random.seed(104)
# X_data = []
# Y_data = []
# start_time = time.time()
# for i in range(sim_rep_time):

#     X_data.append(GetData.Get_X_data(Mean_Func  = X_Mean_Func, 
#                                      Eigen_Funcs = Eigen_Funcs_X, 
#                                      eigen_val  = X_eigen_val, 
#                                      domain = range_X, 
#                                      tran_size  = tran_samp_size, 
#                                      test_size  = test_samp_size,
#                                      num_grid = num_grid_X))


#     #Generate Simulation data of Y

#     Y_data.append(GetData.Get_Y_data(Mean_Func = Y_Mean_Func, 
#                                      Eigen_Funcs = Eigen_Funcs_Y,
#                                      X_fpcs = [X_data[i].fpcs],
#                                      B = [B], 
#                                      domain = range_Y, 
#                                      test_size = test_samp_size, 
#                                      num_grid = num_grid_Y))

#     #Save data
    
#     start_time = time.time()
#     # for 'refund' in R
#     datas = [X_data[i], Y_data[i]]
#     for j in range(2):
#         np.savetxt('tran '+ name[j] + ' of samp ' + np.str(i + 1), np.column_stack((datas[j].obs_tran)), 
#                    newline='\n' ,delimiter = ' ', fmt="%s")
        
#         np.savetxt('test '+ name[j] + ' of samp ' + np.str(i + 1), np.column_stack((datas[j].obs_test)), 
#                    newline='\n', delimiter = ' ', fmt="%s")
        
#         np.savetxt('real_on_grid '+ name[j] + ' of samp ' + np.str(i + 1), np.column_stack((datas[j].real_val_on_grid)), 
#                    newline='\n', delimiter = ' ', fmt="%s")
        
# #         np.savetxt('tran_time_pt '+ name[j] + ' of samp ' + np.str(i + 1), np.column_stack((datas[j].tran_time_pts)), 
# #                    newline='\n', delimiter = ' ', fmt="%s")
        
# #         np.savetxt('test_time_pt '+ name[j] + ' of samp ' + np.str(i + 1), np.column_stack((datas[j].test_time_pts)), 
# #                    newline='\n', delimiter = ' ', fmt="%s")

#     #for 'PACE' in Matlab
#     X_sim_data = {'t': np.bmat([[X_data[i].tran_time_pts],[X_data[i].test_time_pts]]), 
#                   'obs': np.bmat([[X_data[i].obs_tran],[X_data[i].obs_test]]), 
#                   'fpcs': X_data[i].fpcs}
#     Y_sim_data = {'t': np.bmat([[Y_data[i].tran_time_pts],[Y_data[i].test_time_pts]]), 
#                   'obs': np.bmat([[Y_data[i].obs_tran],[Y_data[i].obs_test]]), 
#                   'fpcs': Y_data[i].fpcs,
#                   'real_test_Y': Y_data[i].real_val_on_grid[tran_samp_size:,]}
    
#     sp.io.savemat('d:/Work_Jupyter/敏/SIM_1y1x_grid1_size200/sim_X_data_'+str(i+1)+'.mat', X_sim_data)
#     sp.io.savemat('d:/Work_Jupyter/敏/SIM_1y1x_grid1_size200/sim_Y_data_'+str(i+1)+'.mat', Y_sim_data)
    
# print(time.time()-start_time)
    
# sp.io.savemat('d:/Work_Jupyter/敏/SIM_1y1x_grid1_size200/sim_X_time_grid.mat',
#                 {'grid': X_data[0].time_grid})
# sp.io.savemat('d:/Work_Jupyter/敏/SIM_1y1x_grid1_size200/sim_Y_time_grid.mat',
#                 {'grid': Y_data[0].time_grid})

# %%
X_time_grid = sp.io.loadmat('/home/hot50773/SIM_1y1x_grid1_size200/temp/sim_X_time_grid.mat')['grid'][0]
Y_time_grid = sp.io.loadmat('/home/hot50773/SIM_1y1x_grid1_size200/temp/sim_Y_time_grid.mat')['grid'][0]

# %%
# bandwidth
X_candidate_h_mean = np.arange(0.25, 1.25, 0.05).reshape(-1, 1)
X_candidate_h_cov = np.arange(0.25, 1.25, 0.05).repeat(2).reshape(-1, 2)
X_candidate_h_diag_cov = np.arange(0.25, 1.25, 0.1).reshape(-1, 1)

Y_candidate_h_mean = np.arange(0.25, 1.25, 0.05).reshape(-1, 1)
Y_candidate_h_cov = np.arange(0.25, 1.25, 0.05).repeat(2).reshape(-1, 2)

X_Y_candidate_h_cov = np.asanyarray(np.meshgrid(np.arange(0.3, 0.7, 0.05), 
                                                 np.arange(0.3, 0.7, 0.05))).T.reshape(-1,2)

# %%
#Simulation

my_MISE   = np.zeros(sim_rep_time)
my_RMSPE  = np.zeros(sim_rep_time)
my_MaxAbs = np.zeros(sim_rep_time)
X_data = []
Y_data = []
np.random.seed(104)
for i in range(sim_rep_time):
    start_time = time.time()
    #load data from mat
    X_sim_data_i = sp.io.loadmat('/home/hot50773/SIM_1y1x_grid1_size200/temp/sim_X_data_'+str(i+1)+'.mat')
    Y_sim_data_i = sp.io.loadmat('/home/hot50773/SIM_1y1x_grid1_size200/temp/sim_Y_data_'+str(i+1)+'.mat')
    
    #convert into our data form
    X_data.append(GetData.Load_Data(sim_data = X_sim_data_i,time_grid=X_time_grid, tran_test_size = np.array([tran_samp_size, test_samp_size])))
    Y_data.append(GetData.Load_Data(sim_data = Y_sim_data_i,time_grid=Y_time_grid, response = True,tran_test_size = np.array([tran_samp_size, test_samp_size])))
    
    '''
    Results of X
    '''

    result_X = FFReg.Get_FPCA_Result(X_data[i], X_candidate_h_mean, 
                                      X_candidate_h_cov, X_candidate_h_diag_cov, 
                                      ker_fun = 'Epan', fve = 0.98)
    #fitting test sample
    fit_test_X = result_X.Restruect_Fun(X_data[i].test_time_pts.reshape(test_samp_size, num_pts, 1),
                                         X_data[i].obs_test)[1]

    '''
    Results of Y
    '''


    result_Y = FFReg.Fit_Mean_and_Cov(Y_data[i], Y_candidate_h_mean, 
                                      Y_candidate_h_cov, ker_fun = 'Epan')


    '''
    Construct Coefficient Function

        1. fit cov_Xi_Xj
        2. fit cov_Xi_Y
        3. combine them to build coefficient function

    '''



    fit_cov_XY = FFReg.Fit_Cov_XY(X_time_pts = X_data[i].tran_time_pts,
                                  Y_time_pts = Y_data[i].tran_time_pts,
                                  obs_X = X_data[i].obs_tran, 
                                  obs_Y = Y_data[i].obs_tran,
                                  X_time_grid = X_data[i].time_grid,
                                  Y_time_grid = Y_data[i].time_grid, 
                                  fit_X_mean = result_X.mean_fun, 
                                  fit_Y_mean = result_Y.mean_fun, 
                                  candidate_h_cov = X_Y_candidate_h_cov, 
                                  ker_fun = 'Epan')

    '''
    Coefficient Function
    '''

    fit_cov_XX = result_X.cov_fun

    inv_fit_cov_XX = np.linalg.pinv(fit_cov_XX, rcond= 0.07)

    fit_Beta_without_delta =  np.matmul(inv_fit_cov_XX,fit_cov_XY)

    ## add delta
    if i == 0:
        delta = np.diag(np.repeat([X_data[i].time_grid[1] - X_data[i].time_grid[0]],
                                   [num_grid_X]))
        delta_inv = np.linalg.inv(delta)

    fit_Beta  = np.matmul(delta_inv, fit_Beta_without_delta)


    #---------------------------------------
    # fit Response of test set on grid
    #---------------------------------------
    fit_test_X_center = fit_test_X - result_X.mean_fun


    #compute test_Y(on grid pts)
    fit_test_Y = result_Y.mean_fun + np.matmul(fit_Beta_without_delta.T, fit_test_X_center.T).T


    #real value of test_Y (on grid pts)
    real_test_Y = Y_data[i].real_val_on_grid[tran_samp_size:,:]

    #========================================================
    #compute RMSPE (relative mean squared prediction error)
    #========================================================
    grid_width = Y_data[i].time_grid[1] - Y_data[i].time_grid[0]
#   my_RMSPE[i] = (np.sum(np.square(real_test_Y - fit_test_Y) * grid_width, 1) /np.sum((real_test_Y**2) * grid_width, 1)).mean()
    #======================================
    #compute Mean integrated squared error
    #======================================

    my_MISE[i] = np.sum(np.square(real_test_Y - fit_test_Y) * grid_width, 1).mean()

    # maxima of absolute error
#     my_MaxAbs[i] = np.abs(real_test_Y - fit_test_Y).max()
    
    print(i,' ,time = ', time.time()-start_time)

np.savetxt('MISE_Epan_200size_real_loocv', my_MISE, newline='\n', delimiter = ' ', fmt="%s")
# Out:
# Bandwidth of cov:  [ 0.3  0.3]
# 0  ,time =  26.857051372528076
# Bandwidth of cov:  [ 0.3  0.3]
# 1  ,time =  26.81441640853882
# Bandwidth of cov:  [ 0.3  0.3]
# 2  ,time =  26.77083706855774
# Bandwidth of cov:  [ 0.5  0.5]
# 3  ,time =  26.838936805725098
# Bandwidth of cov:  [ 0.5  0.5]
# 4  ,time =  26.803913831710815
# Bandwidth of cov:  [ 0.5  0.3]
# 5  ,time =  26.870379209518433
# Bandwidth of cov:  [ 0.3  0.3]
# 6  ,time =  26.792006254196167
# Bandwidth of cov:  [ 0.3  0.3]
# 7  ,time =  26.818519115447998
# Bandwidth of cov:  [ 0.3  0.3]
# 8  ,time =  26.802318572998047
# Bandwidth of cov:  [ 0.55  0.65]
# 9  ,time =  26.78436303138733
# Bandwidth of cov:  [ 0.65  0.65]
# 10  ,time =  26.82161259651184
# Bandwidth of cov:  [ 0.3  0.3]
# 11  ,time =  26.765875816345215
# Bandwidth of cov:  [ 0.3  0.3]
# 12  ,time =  26.82184672355652
# Bandwidth of cov:  [ 0.3  0.3]
# 13  ,time =  26.825024366378784
# Bandwidth of cov:  [ 0.3  0.3]
# 14  ,time =  26.80491304397583
# Bandwidth of cov:  [ 0.6  0.6]
# 15  ,time =  26.861215114593506
# Bandwidth of cov:  [ 0.3  0.3]
# 16  ,time =  26.802507638931274
# Bandwidth of cov:  [ 0.45  0.55]
# 17  ,time =  26.817516326904297
# Bandwidth of cov:  [ 0.3  0.3]
# 18  ,time =  26.789191722869873
# Bandwidth of cov:  [ 0.65  0.65]
# 19  ,time =  26.792617559432983
# Bandwidth of cov:  [ 0.65  0.65]
# 20  ,time =  26.76182770729065
# Bandwidth of cov:  [ 0.3  0.3]
# 21  ,time =  26.82057213783264
# Bandwidth of cov:  [ 0.65  0.65]
# 22  ,time =  26.802875518798828
# Bandwidth of cov:  [ 0.3   0.35]
# 23  ,time =  26.83190608024597
# Bandwidth of cov:  [ 0.3  0.3]
# 24  ,time =  26.817769765853882
# Bandwidth of cov:  [ 0.3  0.3]
# 25  ,time =  26.836633682250977
# Bandwidth of cov:  [ 0.35  0.3 ]
# 26  ,time =  26.80792546272278
# Bandwidth of cov:  [ 0.3  0.3]
# 27  ,time =  26.82232904434204
# Bandwidth of cov:  [ 0.55  0.65]
# 28  ,time =  26.88083267211914
# Bandwidth of cov:  [ 0.3  0.3]
# 29  ,time =  26.856471061706543
# Bandwidth of cov:  [ 0.3  0.3]
# 30  ,time =  26.871479034423828
# Bandwidth of cov:  [ 0.3  0.4]
# 31  ,time =  26.82608127593994
# Bandwidth of cov:  [ 0.3  0.3]
# 32  ,time =  26.84652018547058
# Bandwidth of cov:  [ 0.5   0.55]
# 33  ,time =  26.8222336769104
# Bandwidth of cov:  [ 0.3   0.55]
# 34  ,time =  26.81438970565796
# Bandwidth of cov:  [ 0.55  0.55]
# 35  ,time =  26.833412170410156
# Bandwidth of cov:  [ 0.6   0.65]
# 36  ,time =  26.824652433395386
# Bandwidth of cov:  [ 0.3  0.3]
# 37  ,time =  26.837625980377197
# Bandwidth of cov:  [ 0.3  0.3]
# 38  ,time =  26.825818061828613
# Bandwidth of cov:  [ 0.3  0.3]
# 39  ,time =  26.81676983833313
# Bandwidth of cov:  [ 0.3  0.3]
# 40  ,time =  26.83977222442627
# Bandwidth of cov:  [ 0.3  0.3]
# 41  ,time =  26.847156763076782
# Bandwidth of cov:  [ 0.65  0.65]
# 42  ,time =  26.841161489486694
# Bandwidth of cov:  [ 0.65  0.65]
# 43  ,time =  26.90363311767578
# Bandwidth of cov:  [ 0.3  0.3]
# 44  ,time =  26.946367979049683
# Bandwidth of cov:  [ 0.3   0.35]
# 45  ,time =  26.965176105499268
# Bandwidth of cov:  [ 0.3  0.3]
# 46  ,time =  26.94369339942932
# Bandwidth of cov:  [ 0.6  0.6]
# 47  ,time =  26.966438055038452
# Bandwidth of cov:  [ 0.3  0.3]
# 48  ,time =  26.973907947540283
# Bandwidth of cov:  [ 0.3  0.3]
# 49  ,time =  26.964805603027344
# Bandwidth of cov:  [ 0.3  0.3]
# 50  ,time =  26.96646809577942
# Bandwidth of cov:  [ 0.6   0.65]
# 51  ,time =  26.965600967407227
# Bandwidth of cov:  [ 0.3  0.3]
# 52  ,time =  26.944913625717163
# Bandwidth of cov:  [ 0.65  0.65]
# 53  ,time =  26.896185398101807
# Bandwidth of cov:  [ 0.5  0.6]
# 54  ,time =  26.981037616729736
# Bandwidth of cov:  [ 0.55  0.3 ]
# 55  ,time =  26.98939037322998
# Bandwidth of cov:  [ 0.6   0.65]
# 56  ,time =  26.92041301727295
# Bandwidth of cov:  [ 0.3  0.3]
# 57  ,time =  26.9433274269104
# Bandwidth of cov:  [ 0.3  0.3]
# 58  ,time =  26.967750549316406
# Bandwidth of cov:  [ 0.65  0.65]
# 59  ,time =  26.98377823829651
# Bandwidth of cov:  [ 0.3  0.3]
# 60  ,time =  26.933454275131226
# Bandwidth of cov:  [ 0.65  0.65]
# 61  ,time =  26.957762479782104
# Bandwidth of cov:  [ 0.3  0.3]
# 62  ,time =  26.949583292007446
# Bandwidth of cov:  [ 0.3  0.3]
# 63  ,time =  26.95726704597473
# Bandwidth of cov:  [ 0.5  0.5]
# 64  ,time =  26.960323810577393
# Bandwidth of cov:  [ 0.65  0.65]
# 65  ,time =  26.9992036819458
# Bandwidth of cov:  [ 0.55  0.65]
# 66  ,time =  26.956156969070435
# Bandwidth of cov:  [ 0.3  0.3]
# 67  ,time =  26.99782109260559
# Bandwidth of cov:  [ 0.3  0.3]
# 68  ,time =  26.913805723190308
# Bandwidth of cov:  [ 0.55  0.5 ]
# 69  ,time =  26.975706577301025
# Bandwidth of cov:  [ 0.65  0.6 ]
# 70  ,time =  26.801380395889282
# Bandwidth of cov:  [ 0.3  0.3]
# 71  ,time =  26.754270315170288
# Bandwidth of cov:  [ 0.3  0.3]
# 72  ,time =  26.762428522109985
# Bandwidth of cov:  [ 0.3  0.3]
# 73  ,time =  26.7399959564209
# Bandwidth of cov:  [ 0.5  0.5]
# 74  ,time =  26.820784330368042
# Bandwidth of cov:  [ 0.6  0.6]
# 75  ,time =  26.81532382965088
# Bandwidth of cov:  [ 0.5   0.45]
# 76  ,time =  26.843201398849487
# Bandwidth of cov:  [ 0.3  0.3]
# 77  ,time =  26.846622705459595
# Bandwidth of cov:  [ 0.65  0.65]
# 78  ,time =  26.760880708694458
# Bandwidth of cov:  [ 0.65  0.65]
# 79  ,time =  26.802477836608887
# Bandwidth of cov:  [ 0.6   0.65]
# 80  ,time =  26.775214195251465
# Bandwidth of cov:  [ 0.65  0.65]
# 81  ,time =  26.999531269073486
# Bandwidth of cov:  [ 0.3  0.3]
# 82  ,time =  26.946352243423462
# Bandwidth of cov:  [ 0.3  0.3]
# 83  ,time =  26.89095187187195
# Bandwidth of cov:  [ 0.3  0.3]
# 84  ,time =  26.973275899887085
# Bandwidth of cov:  [ 0.3  0.3]
# 85  ,time =  26.97361707687378
# Bandwidth of cov:  [ 0.3  0.3]
# 86  ,time =  26.927236318588257
# Bandwidth of cov:  [ 0.3  0.3]
# 87  ,time =  26.95293164253235
# Bandwidth of cov:  [ 0.5  0.3]
# 88  ,time =  26.9574236869812
# Bandwidth of cov:  [ 0.6  0.3]
# 89  ,time =  26.920517206192017
# Bandwidth of cov:  [ 0.5  0.6]
# 90  ,time =  26.951868772506714
# Bandwidth of cov:  [ 0.65  0.65]
# 91  ,time =  26.949390172958374
# Bandwidth of cov:  [ 0.3  0.3]
# 92  ,time =  26.959064960479736
# Bandwidth of cov:  [ 0.3  0.3]
# 93  ,time =  27.03826355934143
# Bandwidth of cov:  [ 0.4   0.55]
# 94  ,time =  26.92033886909485
# Bandwidth of cov:  [ 0.5  0.6]
# 95  ,time =  26.90910792350769
# Bandwidth of cov:  [ 0.65  0.65]
# 96  ,time =  26.897302865982056
# Bandwidth of cov:  [ 0.3  0.3]
# 97  ,time =  26.793681621551514
# Bandwidth of cov:  [ 0.6  0.5]
# 98  ,time =  26.820935487747192
# Bandwidth of cov:  [ 0.6  0.6]
# 99  ,time =  26.8148775100708

# %%
import scipy as sp
from scipy import io
import numpy as np

# %%
my_MISE = np.loadtxt('MISE_Epan_200size_real_loocv')

# %%
PACE_result = sp.io.loadmat('D:/Work_Jupyter/敏/SIM_1y1x_grid1_size200/result_PACE_grid.mat')

# %%
refund_ff_MISE = 5 * np.loadtxt('refundFF_MISE_200size', delimiter = ' ')

# %%
refund_fpc_MISE = 5 * np.loadtxt('refundFPC_MISE_200size', delimiter = ' ')

# %%
# create the quantile value of each array
# save in tuple

quantile_PACE_MISE  = []
quantile_my_MISE  = []
quantile_refund_ff_MISE  = []
quantile_refund_fpc_MISE  = []

#add mean        
quantile_PACE_MISE.append(np.asscalar(np.mean(PACE_result['MISE'])))
quantile_my_MISE.append(np.asscalar(np.mean(my_MISE)))
quantile_refund_ff_MISE.append(np.asscalar(np.mean(refund_ff_MISE)))
quantile_refund_fpc_MISE.append(np.asscalar(np.mean(refund_fpc_MISE)))

#add median
quantile_PACE_MISE.append(np.asscalar(np.median(PACE_result['MISE'])))
quantile_my_MISE.append(np.asscalar(np.median(my_MISE)))
quantile_refund_ff_MISE.append(np.asscalar(np.median(refund_ff_MISE)))
quantile_refund_fpc_MISE.append(np.asscalar(np.median(refund_fpc_MISE)))

#add std

quantile_PACE_MISE.append(np.asscalar(np.std(PACE_result['MISE'])))
quantile_my_MISE.append(np.asscalar(np.std(my_MISE)))
quantile_refund_ff_MISE.append(np.asscalar(np.std(refund_ff_MISE)))
quantile_refund_fpc_MISE.append(np.asscalar(np.std(refund_fpc_MISE)))

#convert to tuple
quantile_PACE_MISE = tuple(quantile_PACE_MISE)
quantile_my_MISE = tuple(quantile_my_MISE)
quantile_refund_ff_MISE = tuple(quantile_refund_ff_MISE)
quantile_refund_fpc_MISE = tuple(quantile_refund_fpc_MISE)

# %%
# print table
# compare MISE of 'PACE'(from matlab) and FFReg
print("====================================================")
print("      Compare Mean Integrated Squared Error         ")
print("====================================================")
print("|   n = 200    |   mean   |   median   |    std    |")
print("----------------------------------------------------")
print(" PACE in matlab" ,3 * " %10.3f"%quantile_PACE_MISE[:3])
print("----------------------------------------------------")
print("   my  method  " ,3 * " %10.3f"%quantile_my_MISE[:3])
print("----------------------------------------------------")
print("   refund_ff   " ,3 * " %10.3f"%quantile_refund_ff_MISE[:3])
print("----------------------------------------------------")
print("   refund_fpc  " ,3 * " %10.3f"%quantile_refund_fpc_MISE[:3])
print("====================================================")
# Out:
# ====================================================
#       Compare Mean Integrated Squared Error
# ====================================================
# |   n = 200    |   mean   |   median   |    std    |
# ----------------------------------------------------
#  PACE in matlab       4.745      5.345      1.764
# ----------------------------------------------------
#    my  method         0.347      0.330      0.109
# ----------------------------------------------------
#    refund_ff          0.378      0.380      0.037
# ----------------------------------------------------
#    refund_fpc         0.325      0.322      0.031
# ====================================================
